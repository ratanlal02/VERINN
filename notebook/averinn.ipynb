# %% [markdown]
# #### **Enter into /content/ folder**

# %%
cd /content/
# Out:
# /content

# %% [markdown]
# #### **Before cloning AVERINN tool, we remove AVERINN folder from /content/ if already exist**

# %%
import shutil
import os

folder_path = "/content/AVERINN"   # change this to your folder

if os.path.exists(folder_path):
    shutil.rmtree(folder_path)
    print("Folder removed successfully!")
else:
    print("Folder does not exist.")
# Out:
# Folder removed successfully!

# %% [markdown]
# #### **Clone AVERINN tool from a github repository**

# %%
# !git clone https://github.com/ratanlal02/AVERINN.git
# Out:
# Cloning into 'AVERINN'...
# remote: Enumerating objects: 671, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 671 (delta 120), reused 152 (delta 73), pack-reused 443 (from 1)
# Receiving objects: 100% (671/671), 111.73 MiB | 30.78 MiB/s, done.
# Resolving deltas: 100% (290/290), done.

# %% [markdown]
# #### **Enter into AVERINN folder**

# %%
cd /content/AVERINN/
# Out:
# /content/AVERINN

# %% [markdown]
# #### **Install required packages**

# %%
# !python -m pip install -r requirements.txt

# %% [markdown]
# #### **Test Reachability or Safety of neural networks using AVERINN tool**

# %%
# nn-cnfig.ini file is the place where you provide all the information
# about the system, specification, and problem to solve
! python -m nn-averinn nn-config.ini

# %% [markdown]
# #### **Output for Neural Networks for Reachability/Safety**

# %%
file_path = "log.txt"

with open(file_path, "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# #### **Test Reachability or Safety of neural network controlled systems using AVERINN tool**

# %%
# nncs-cnfig.ini file is the place where you provide all the information
# about the system, specification, and problem to solve
! python -m nncs-averinn nncs-config.ini

# %% [markdown]
# #### **Output for Neural Network Control Systems for Reachability/Safety**

# %%
file_path = "log.txt"

with open(file_path, "r") as file:
    content = file.read()
    print(content)
